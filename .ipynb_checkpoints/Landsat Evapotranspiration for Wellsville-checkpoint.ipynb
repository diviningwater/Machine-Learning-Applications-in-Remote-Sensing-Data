# %% [markdown]
# # Landsat ET using OpenET SSEBop algorithm
# ## Collection "Overpass" Examples

# %%
import datetime
import pprint

import ee
import pandas as pd

from IPython.display import Image
import openet.ssebop as model

ee.Initialize()

# %%
ndvi_palette = ['DEC29B', 'E6CDA1', 'EDD9A6', 'F5E4A9', 'FFF4AD', 'C3E683', '6BCC5C', 
    '3BB369', '20998F', '1C8691', '16678A', '114982', '0B2C7A']
et_palette = [
    'DEC29B', 'E6CDA1', 'EDD9A6', 'F5E4A9', 'FFF4AD', 'C3E683', '6BCC5C', 
    '3BB369', '20998F', '1C8691', '16678A', '114982', '0B2C7A']

# %% [markdown]
# ### Input parameters

# %%
collections = ['LANDSAT/LC08/C01/T1_TOA']

# etr_source = 'projects/climate-engine/cimis/daily'
# etr_band = 'ETr_ASCE'
etr_source = 'IDAHO_EPSCOR/GRIDMET'
etr_band = 'etr'

# Date range you want to aggregate ET over
# End date is inclusive (like filterDate() calls)
start_date = '2019-02-01'
end_date = '2019-12-01'

# Only keep images with an average cloud cover less than
# Cloud cover filter parameter is not being passed in (yet)
cloud_cover = 70

# Number of extra days (at start and end) to include in interpolation
interp_days = 32
# Interpolation method - currently only LINEAR is supported
interp_method = 'LINEAR'

test_point = ee.Geometry.Point(-111.920206, 41.661929)
study_area = ee.Geometry.Rectangle(-111.929757, 41.667917, -111.912120, 41.657761)

# Hard code the study area and CRS
study_region = study_area.bounds(1, 'EPSG:4326').coordinates().getInfo() #WGS84
study_crs = 'EPSG:32612' #WGS84 UTM 12

# %%
image = ee.Image(ee.ImageCollection('USDA/NAIP/DOQQ').filterBounds(study_area).first());
#// Add the image to the map.
Image(url = image.getThumbURL({'region': study_region}),
      embed=True, format='png')

# %% [markdown]
# ### Landsat 8 Collection 1 TOA Image Collection

# %%
model_obj = model.Collection(
    collections=collections,
    etr_source=etr_source, 
    etr_band=etr_band,
    start_date=start_date,
    end_date=end_date,
    geometry=test_point,
    cloud_cover_max=70,
    # filter_args={},
)
pprint.pprint(model_obj.get_image_ids())
# Out:
# ['LANDSAT/LC08/C01/T1_TOA/LC08_038031_20190218',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_038031_20190423',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_038031_20190525',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_038031_20190610',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_038031_20190626',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_038031_20190712',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_038031_20190728',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_038031_20190813',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_038031_20190829',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_038031_20190914',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_038031_20190930',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_038031_20191016',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_039031_20190601',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_039031_20190617',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_039031_20190703',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_039031_20190719',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_039031_20190804',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_039031_20190820',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_039031_20190905',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_039031_20190921',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_039031_20191007',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_039031_20191023']

# %%
def get_region_df(info):
    """Convert the output of getRegions to a pandas dataframe"""
    col_dict = {}
    info_dict = {}
    for i, k in enumerate(info[0][4:]):
        col_dict[k] = i+4
        info_dict[k] = {}
        
    for row in info[1:]:
        date = datetime.datetime.utcfromtimestamp(row[3] / 1000.0).strftime('%Y-%m-%d')
        for k, v in col_dict.items():
            info_dict[k][date] = row[col_dict[k]]
            
    return pd.DataFrame.from_dict(info_dict)

# %% [markdown]
# ## "Overpass" Collection

# %%
overpass_coll = model_obj.overpass(variables=['ndvi', 'et', 'etr', 'etf'])

# %%
overpass_df = get_region_df(overpass_coll.getRegion(test_point, scale=30).getInfo())
pprint.pprint(overpass_df)
print('')
pprint.pprint(overpass_df[['et', 'etr']].sum())
# Out:
#                 ndvi        et        etr       etf
# 2019-02-18       NaN       NaN        NaN       NaN
# 2019-04-23  0.252925  0.000000   4.991673  0.000000
# 2019-05-25  0.256901  1.703553   5.308395  0.320917
# 2019-06-10  0.304030  0.000000   7.200000  0.000000
# 2019-06-26  0.324506  5.762634  10.400000  0.554100
# 2019-07-12  0.503983  2.614367   8.900000  0.293749
# 2019-07-28  0.779524  7.878270   8.400000  0.937889
# 2019-08-13  0.824214  5.621595   7.000000  0.803085
# 2019-08-29  0.703357  6.672411   6.700000  0.995882
# 2019-09-14  0.789104  4.105762   6.300000  0.651708
# 2019-09-30  0.734607  2.310000   2.200000  1.050000
# 2019-10-16  0.232709  0.000000   4.300000  0.000000
# 2019-06-01       NaN       NaN        NaN       NaN
# 2019-06-17       NaN       NaN        NaN       NaN
# 2019-07-03       NaN       NaN        NaN       NaN
# 2019-07-19  0.631452  3.281599   9.000000  0.364622
# 2019-08-04  0.771980  5.423866   9.500000  0.570933
# 2019-08-20  0.835263  4.866956   8.500000  0.572583
# 2019-09-05  0.774771  0.999647   6.500000  0.153792
# 2019-09-21  0.666197  2.809748   2.700000  1.040647
# 2019-10-07       NaN       NaN        NaN       NaN
# 2019-10-23       NaN       NaN        NaN       NaN
#
# et      54.050407
# etr    107.900067
# dtype: float64

# %% [markdown]
# ### NDVI

# %%
Image(url=ee.Image(overpass_coll.select(['ndvi']).median())\
          .reproject(crs=study_crs, scale=30)\
          .getThumbURL({'min': 0, 'max': 1.0, 'palette': ','.join(ndvi_palette), 
                              'region': study_region}),
      embed=True, format='png')

# %% [markdown]
# ### ET fraction

# %%
Image(url=ee.Image(overpass_coll.select(['etf']).median())\
          .reproject(crs=study_crs, scale=30)\
          .getThumbURL({'min': 0.0, 'max': 1.2, 'palette': ','.join(et_palette), 
                        'region': study_region}),
      embed=True, format='png')

# %% [markdown]
# ### Reference ET (from Idaho Gridmet)

# %%
Image(url=ee.Image(overpass_coll.select(['etr']).median())\
          .reproject(crs=study_crs, scale=30)\
          .getThumbURL({'min': 0.0, 'max': 12, 'palette': ','.join(et_palette), 
                        'region': study_region}),
      embed=True, format='png')

# %% [markdown]
# ### ET

# %%
Image(url=ee.Image(overpass_coll.select(['et']).mean())\
          .reproject(crs=study_crs, scale=30)\
          .getThumbURL({'min': 0.0, 'max':7, 'palette': ','.join(et_palette), 
                              'region': study_region}),
      embed=True, format='png')
